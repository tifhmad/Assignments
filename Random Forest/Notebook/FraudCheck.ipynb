# %% [markdown]
# # Use Random Forest to prepare a model on fraud data
# treating those who have taxable_income <= 30000 as "Risky" and others are "Good"

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fraud=pd.read_csv('/content/Fraud_check (1).csv')

# %%
fraud
# Out:
#     Undergrad Marital.Status  Taxable.Income  City.Population  \
# 0          NO         Single           68833            50047
# 1         YES       Divorced           33700           134075
# 2          NO        Married           36925           160205
# 3         YES         Single           50190           193264
# 4          NO        Married           81002            27533
# ..        ...            ...             ...              ...
# 595       YES       Divorced           76340            39492
# 596       YES       Divorced           69967            55369
# 597        NO       Divorced           47334           154058
# 598       YES        Married           98592           180083
# 599        NO       Divorced           96519           158137
#
#      Work.Experience Urban
# 0                 10   YES
# 1                 18   YES
# 2                 30   YES
# 3                 15   YES
# 4                 28    NO
# ..               ...   ...
# 595                7   YES
# 596                2   YES
# 597                0   YES
# 598               17    NO
# 599               16    NO
#
# [600 rows x 6 columns]

# %%
fraud=fraud.rename(columns={'Marital.Status':'marital_status','Taxable.Income':'taxable_income','City.Population':'city_population','Work.Experience':'wrok_experience'})

# %%
fraud
# Out:
#     Undergrad marital_status  taxable_income  city_population  \
# 0          NO         Single           68833            50047
# 1         YES       Divorced           33700           134075
# 2          NO        Married           36925           160205
# 3         YES         Single           50190           193264
# 4          NO        Married           81002            27533
# ..        ...            ...             ...              ...
# 595       YES       Divorced           76340            39492
# 596       YES       Divorced           69967            55369
# 597        NO       Divorced           47334           154058
# 598       YES        Married           98592           180083
# 599        NO       Divorced           96519           158137
#
#      wrok_experience Urban
# 0                 10   YES
# 1                 18   YES
# 2                 30   YES
# 3                 15   YES
# 4                 28    NO
# ..               ...   ...
# 595                7   YES
# 596                2   YES
# 597                0   YES
# 598               17    NO
# 599               16    NO
#
# [600 rows x 6 columns]

# %%
fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Undergrad        600 non-null    object
#  1   marital_status   600 non-null    object
#  2   taxable_income   600 non-null    int64
#  3   city_population  600 non-null    int64
#  4   wrok_experience  600 non-null    int64
#  5   Urban            600 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 28.2+ KB

# %%
fraud.describe()
# Out:
#        taxable_income  city_population  wrok_experience
# count      600.000000       600.000000       600.000000
# mean     55208.375000    108747.368333        15.558333
# std      26204.827597     49850.075134         8.842147
# min      10003.000000     25779.000000         0.000000
# 25%      32871.500000     66966.750000         8.000000
# 50%      55074.500000    106493.500000        15.000000
# 75%      78611.750000    150114.250000        24.000000
# max      99619.000000    199778.000000        30.000000

# %%
def split(num):
  if num <30000:
    return 'Risky'
  else:
    return 'Good'
fraud.taxable_income=fraud.taxable_income.apply(split)

# %%
fraud
# Out:
#     Undergrad marital_status taxable_income  city_population  wrok_experience  \
# 0          NO         Single           Good            50047               10
# 1         YES       Divorced           Good           134075               18
# 2          NO        Married           Good           160205               30
# 3         YES         Single           Good           193264               15
# 4          NO        Married           Good            27533               28
# ..        ...            ...            ...              ...              ...
# 595       YES       Divorced           Good            39492                7
# 596       YES       Divorced           Good            55369                2
# 597        NO       Divorced           Good           154058                0
# 598       YES        Married           Good           180083               17
# 599        NO       Divorced           Good           158137               16
#
#     Urban
# 0     YES
# 1     YES
# 2     YES
# 3     YES
# 4      NO
# ..    ...
# 595   YES
# 596   YES
# 597   YES
# 598    NO
# 599    NO
#
# [600 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
fraud['Undergrad']=le.fit_transform(fraud['Undergrad'])
fraud['marital_status']=le.fit_transform(fraud['marital_status'])
fraud['Urban']=le.fit_transform(fraud['Urban'])

# %%
fraud
# Out:
#      Undergrad  marital_status taxable_income  city_population  \
# 0            0               2           Good            50047
# 1            1               0           Good           134075
# 2            0               1           Good           160205
# 3            1               2           Good           193264
# 4            0               1           Good            27533
# ..         ...             ...            ...              ...
# 595          1               0           Good            39492
# 596          1               0           Good            55369
# 597          0               0           Good           154058
# 598          1               1           Good           180083
# 599          0               0           Good           158137
#
#      wrok_experience  Urban
# 0                 10      1
# 1                 18      1
# 2                 30      1
# 3                 15      1
# 4                 28      0
# ..               ...    ...
# 595                7      1
# 596                2      1
# 597                0      1
# 598               17      0
# 599               16      0
#
# [600 rows x 6 columns]

# %%
import seaborn as sns
sns.pairplot(fraud)

# %%
corr=fraud.corr()
import seaborn as sns
sns.heatmap(corr,annot=True)

# %%
x=fraud.iloc[:,fraud.columns!='taxable_income']
y=fraud['taxable_income']

# %%
x
# Out:
#      Undergrad  marital_status  city_population  wrok_experience  Urban
# 0            0               2            50047               10      1
# 1            1               0           134075               18      1
# 2            0               1           160205               30      1
# 3            1               2           193264               15      1
# 4            0               1            27533               28      0
# ..         ...             ...              ...              ...    ...
# 595          1               0            39492                7      1
# 596          1               0            55369                2      1
# 597          0               0           154058                0      1
# 598          1               1           180083               17      0
# 599          0               0           158137               16      0
#
# [600 rows x 5 columns]

# %%
y
# Out:
# 0      Good
# 1      Good
# 2      Good
# 3      Good
# 4      Good
#        ...
# 595    Good
# 596    Good
# 597    Good
# 598    Good
# 599    Good
# Name: taxable_income, Length: 600, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
model=RandomForestClassifier(n_jobs=3,oob_score=True,n_estimators=15,criterion='entropy')
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/ensemble/_forest.py:560: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable OOB estimates.
#   warn(
# RandomForestClassifier(criterion='entropy', n_estimators=15, n_jobs=3,
#                        oob_score=True)

# %%
pred=model.predict(x_test)

# %%
pred
# Out:
# array(['Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Risky',
#        'Good', 'Good', 'Risky', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Risky', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Risky', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Risky', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Risky', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Risky',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Risky',
#        'Good', 'Risky', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good'], dtype=object)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
accuracy_score(y_test,pred)
# Out:
# 0.7555555555555555

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[135,   8],
#        [ 36,   1]])

# %%
df=pd.DataFrame({'actual':y_test,'predicted':pred})
df
# Out:
#     actual predicted
# 110  Risky      Good
# 419   Good      Good
# 565   Good      Good
# 77    Good      Good
# 181  Risky      Good
# ..     ...       ...
# 54    Good      Good
# 493  Risky      Good
# 46    Good      Good
# 93   Risky      Good
# 264   Good      Good
#
# [180 rows x 2 columns]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#         Good       0.79      0.94      0.86       143
#        Risky       0.11      0.03      0.04        37
#
#     accuracy                           0.76       180
#    macro avg       0.45      0.49      0.45       180
# weighted avg       0.65      0.76      0.69       180
