# %% [markdown]
# Prepare a prediction model for profit of 50_startups data.
# Do transformations for getting better predictions of profit and
# make a table containing R^2 value for each prepared model.
#
# R&D Spend -- Research and devolop spend in the past few years
# Administration -- spend on administration in the past few years
# Marketing Spend -- spend on Marketing in the past few years
# State -- states from which data is collected
# Profit  -- profit of each state in the past few years

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf

# %%
df=pd.read_csv('/content/50_Startups.csv')

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.values
# Out:
# array([[165349.2, 136897.8, 471784.1, 'New York', 192261.83],
#        [162597.7, 151377.59, 443898.53, 'California', 191792.06],
#        [153441.51, 101145.55, 407934.54, 'Florida', 191050.39],
#        [144372.41, 118671.85, 383199.62, 'New York', 182901.99],
#        [142107.34, 91391.77, 366168.42, 'Florida', 166187.94],
#        [131876.9, 99814.71, 362861.36, 'New York', 156991.12],
#        [134615.46, 147198.87, 127716.82, 'California', 156122.51],
#        [130298.13, 145530.06, 323876.68, 'Florida', 155752.6],
#        [120542.52, 148718.95, 311613.29, 'New York', 152211.77],
#        [123334.88, 108679.17, 304981.62, 'California', 149759.96],
#        [101913.08, 110594.11, 229160.95, 'Florida', 146121.95],
#        [100671.96, 91790.61, 249744.55, 'California', 144259.4],
#        [93863.75, 127320.38, 249839.44, 'Florida', 141585.52],
#        [91992.39, 135495.07, 252664.93, 'California', 134307.35],
#        [119943.24, 156547.42, 256512.92, 'Florida', 132602.65],
# ...

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
df.Profit.describe()
# Out:
# count        50.000000
# mean     112012.639200
# std       40306.180338
# min       14681.400000
# 25%       90138.902500
# 50%      107978.190000
# 75%      139765.977500
# max      192261.830000
# Name: Profit, dtype: float64

# %%
df_rank=df.groupby(['State'])
df_rank.mean()
# Out:
#                R&D Spend  Administration  Marketing Spend         Profit
# State
# California  64657.674118   120746.507059    182540.929412  103905.175294
# Florida     80724.016250   121768.897500    247323.551250  118774.024375
# New York    76195.062353   121543.470588    205346.015882  113756.446471

# %%
df=pd.get_dummies(df,['State'])

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  State_California  \
# 0   165349.20       136897.80        471784.10  192261.83                 0
# 1   162597.70       151377.59        443898.53  191792.06                 1
# 2   153441.51       101145.55        407934.54  191050.39                 0
# 3   144372.41       118671.85        383199.62  182901.99                 0
# 4   142107.34        91391.77        366168.42  166187.94                 0
# 5   131876.90        99814.71        362861.36  156991.12                 0
# 6   134615.46       147198.87        127716.82  156122.51                 1
# 7   130298.13       145530.06        323876.68  155752.60                 0
# 8   120542.52       148718.95        311613.29  152211.77                 0
# 9   123334.88       108679.17        304981.62  149759.96                 1
# 10  101913.08       110594.11        229160.95  146121.95                 0
# ...

# %%
df.corr()
# Out:
#                   R&D Spend  Administration  Marketing Spend    Profit  \
# R&D Spend          1.000000        0.241955         0.724248  0.972900
# Administration     0.241955        1.000000        -0.032154  0.200717
# Marketing Spend    0.724248       -0.032154         1.000000  0.747766
# Profit             0.972900        0.200717         0.747766  1.000000
# State_California  -0.143165       -0.015478        -0.168875 -0.145837
# State_Florida      0.105711        0.010493         0.205685  0.116244
# State_New York     0.039068        0.005145        -0.033670  0.031368
#
#                   State_California  State_Florida  State_New York
# R&D Spend                -0.143165       0.105711        0.039068
# Administration           -0.015478       0.010493        0.005145
# Marketing Spend          -0.168875       0.205685       -0.033670
# Profit                   -0.145837       0.116244        0.031368
# State_California          1.000000      -0.492366       -0.515152
# ...

# %%
df1=df.drop('State_New York',axis=1)

# %%
df1
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  State_California  \
# 0   165349.20       136897.80        471784.10  192261.83                 0
# 1   162597.70       151377.59        443898.53  191792.06                 1
# 2   153441.51       101145.55        407934.54  191050.39                 0
# 3   144372.41       118671.85        383199.62  182901.99                 0
# 4   142107.34        91391.77        366168.42  166187.94                 0
# 5   131876.90        99814.71        362861.36  156991.12                 0
# 6   134615.46       147198.87        127716.82  156122.51                 1
# 7   130298.13       145530.06        323876.68  155752.60                 0
# 8   120542.52       148718.95        311613.29  152211.77                 0
# 9   123334.88       108679.17        304981.62  149759.96                 1
# 10  101913.08       110594.11        229160.95  146121.95                 0
# ...

# %%
df1.isna().sum()
# Out:
# R&D Spend           0
# Administration      0
# Marketing Spend     0
# Profit              0
# State_California    0
# State_Florida       0
# dtype: int64

# %%
df1.corr()
# Out:
#                   R&D Spend  Administration  Marketing Spend    Profit  \
# R&D Spend          1.000000        0.241955         0.724248  0.972900
# Administration     0.241955        1.000000        -0.032154  0.200717
# Marketing Spend    0.724248       -0.032154         1.000000  0.747766
# Profit             0.972900        0.200717         0.747766  1.000000
# State_California  -0.143165       -0.015478        -0.168875 -0.145837
# State_Florida      0.105711        0.010493         0.205685  0.116244
#
#                   State_California  State_Florida
# R&D Spend                -0.143165       0.105711
# Administration           -0.015478       0.010493
# Marketing Spend          -0.168875       0.205685
# Profit                   -0.145837       0.116244
# State_California          1.000000      -0.492366
# State_Florida            -0.492366       1.000000

# %%
#scatterplots between variables along with histogram

# %%
sns.set_style(style='whitegrid')
sns.pairplot(df1)

# %%
Y=df1.iloc[:,3]

# %%
Y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
X=df1.iloc[:,df1.columns !='Profit']

# %%
X
# Out:
#     R&D Spend  Administration  Marketing Spend  State_California  \
# 0   165349.20       136897.80        471784.10                 0
# 1   162597.70       151377.59        443898.53                 1
# 2   153441.51       101145.55        407934.54                 0
# 3   144372.41       118671.85        383199.62                 0
# 4   142107.34        91391.77        366168.42                 0
# 5   131876.90        99814.71        362861.36                 0
# 6   134615.46       147198.87        127716.82                 1
# 7   130298.13       145530.06        323876.68                 0
# 8   120542.52       148718.95        311613.29                 0
# 9   123334.88       108679.17        304981.62                 1
# 10  101913.08       110594.11        229160.95                 0
# 11  100671.96        91790.61        249744.55                 1
# 12   93863.75       127320.38        249839.44                 0
# ...

# %%
df1.rename({"R&D Spend":"RD","Administration":"Admin","Marketing Spend":"Marketing","State_California":"California","State_Florida":"florida"},axis=1,inplace=True)

# %%
df1.head()
# Out:
#           RD      Admin  Marketing     Profit  California  florida
# 0  165349.20  136897.80  471784.10  192261.83           0        0
# 1  162597.70  151377.59  443898.53  191792.06           1        0
# 2  153441.51  101145.55  407934.54  191050.39           0        1
# 3  144372.41  118671.85  383199.62  182901.99           0        0
# 4  142107.34   91391.77  366168.42  166187.94           0        1

# %%
model=smf.ols("Profit~RD+Admin+Marketing+California+florida",data=df1).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     169.9
# Date:                Thu, 01 Dec 2022   Prob (F-statistic):           1.34e-27
# Time:                        16:21:48   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1063.
# Df Residuals:                      44   BIC:                             1074.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.008e+04   6952.587      7.204      0.000    3.61e+04    6.41e+04
# ...

# %%
model.rsquared
# Out:
# 0.9507524843355148

# %%
vif1=smf.ols('RD~Admin+Marketing+California+florida',data=df1).fit().rsquared

# %%
vif_rd=1/(1-vif1)

# %%
vif2=smf.ols('Admin~RD+Marketing+California+florida',data=df1).fit().rsquared

# %%
vif_admin=1/(1-vif2)
vif_admin
# Out:
# 1.1777660508993844

# %%
vif3=smf.ols('Marketing~RD+Admin+California+florida',data=df1).fit().rsquared

# %%
vif_marketing=1/(1-vif3)
vif_marketing
# Out:
# 2.4167967566863933

# %%
vif4=smf.ols('California~RD+Admin+Marketing+florida',data=df1).fit().rsquared

# %%
vif_california=1/(1-vif4)
vif_california
# Out:
# 1.3350608769628542

# %%
vif5=smf.ols('florida~RD+Admin+Marketing+California',data=df1).fit().rsquared

# %%
vif_florida=1/(1-vif5)
vif_florida
# Out:
# 1.3612992664384325

# %%
vifvalues=pd.DataFrame({"variables":['RD','Admin','Marketing','California','florida'],"vif":[2.49,1.17,2.41,1.33,1.36]})

# %%
vifvalues
# Out:
#     variables   vif
# 0          RD  2.49
# 1       Admin  1.17
# 2   Marketing  2.41
# 3  California  1.33
# 4     florida  1.36

# %%
model.resid
# Out:
# 0      -128.741364
# 1      2720.739894
# 2      8774.203265
# 3      9317.013809
# 4     -6089.193819
# 5     -6482.687120
# 6     -1976.782788
# 7     -4403.044651
# 8       577.026673
# 9     -5069.702529
# 10    10457.307408
# 11     8730.799217
# 12    12302.602193
# 13     6876.101014
# 14   -17091.732777
# 15   -16226.595515
# 16    10138.855472
# 17    -4715.039933
# 18    -4882.825743
# 19     7182.671590
# 20     1903.295561
# 21    -5888.485088
# 22    -4481.055137
# 23    -1389.806104
# 24    -4742.333453
# 25     5204.071081
# 26    -5031.761170
# 27    -9271.494028
# 28     1463.792613
# 29     -716.402030
# 30      308.579462
# 31     -133.736321
# 32    -1560.396605
# 33    -1282.438947
# 34     7738.095839
# 35     6059.500395
# 36    15285.097137
# 37      371.437779
# 38    11622.538393
# 39    -2679.216039
# 40     3477.163826
# 41     2842.518953
# 42      922.496288
# 43     9658.711782
# 44      615.182788
# 45    17337.715291
# 46    -6782.242680
# ...

# %%
model.fittedvalues
# Out:
# 0     192390.571364
# 1     189071.320106
# 2     182276.186735
# 3     173584.976191
# 4     172277.133819
# 5     163473.807120
# 6     158099.292788
# 7     160155.644651
# 8     151634.743327
# 9     154829.662529
# 10    135664.642592
# 11    135528.600783
# 12    129282.917807
# 13    127431.248986
# 14    149694.382777
# 15    146143.635515
# 16    116854.074528
# 17    130085.409933
# 18    129149.725743
# 19    115594.188410
# 20    116570.734439
# 21    117201.505088
# 22    114833.305137
# 23    110123.796104
# 24    113294.373453
# 25    102200.268919
# 26    110765.301170
# 27    114279.804028
# 28    101818.587387
# 29    101721.042030
# 30     99629.010538
# 31     97617.296321
# 32     98988.236605
# 33     98061.358947
# 34     88974.704161
# 35     90420.009605
# 36     75423.092863
# 37     89577.702221
# 38     69606.521607
# 39     83684.976039
# 40     74762.746174
# 41     74956.311047
# 42     70575.993712
# 43     60100.268218
# 44     64585.147212
# ...

# %%
sns.boxplot(model.resid)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
def get_Standardized_values(vals):
  return(vals-vals.mean())/vals.std()

# %%
plt.scatter(get_Standardized_values(model.fittedvalues),
            get_Standardized_values(model.resid))
print(get_Standardized_values(model.fittedvalues))
print(get_Standardized_values(model.resid))
plt.xlabel=('Standardized Fitted Values')
plt.ylabel=('Standard Residuals')
plt.show()
# Out:
# 0     2.045180
# 1     1.960723
# 2     1.787824
# 3     1.566680
# 4     1.533402
# 5     1.309406
# 6     1.172654
# 7     1.224977
# 8     1.008166
# 9     1.089460
# 10    0.601814
# 11    0.598353
# 12    0.439434
# 13    0.392319
# 14    0.958795
# 15    0.868448
# 16    0.123188
# 17    0.459853
# 18    0.436045
# 19    0.091131
# 20    0.115979
# 21    0.132028
# 22    0.071771
# 23   -0.048061
# 24    0.032613
# 25   -0.249671
# 26   -0.031738
# 27    0.057687
# 28   -0.259383
# 29   -0.261865
# 30   -0.315096
# 31   -0.366283
# 32   -0.331400
# 33   -0.354984
# 34   -0.586190
# 35   -0.549415
# 36   -0.931004
# 37   -0.570847
# 38   -1.079004
# 39   -0.720784
# 40   -0.947806
# 41   -0.942881
# 42   -1.054336
# 43   -1.320886
# 44   -1.206771
# 45   -1.639246
# 46   -1.418270
# 47   -1.667747
# 48   -1.600196
# 49   -1.624064
# dtype: float64
# 0    -0.014393
# 1     0.304175
# 2     0.980943
# 3     1.041629
# 4    -0.680763
# 5    -0.724755
# 6    -0.221001
# ...

# %%
df1.head(5)
# Out:
#           RD      Admin  Marketing     Profit  California  florida
# 0  165349.20  136897.80  471784.10  192261.83           0        0
# 1  162597.70  151377.59  443898.53  191792.06           1        0
# 2  153441.51  101145.55  407934.54  191050.39           0        1
# 3  144372.41  118671.85  383199.62  182901.99           0        0
# 4  142107.34   91391.77  366168.42  166187.94           0        1

# %%
import statsmodels.api as sm
fig=plt.figure(figsize=(15,8))
fig=sm.graphics.plot_regress_exog(model,'RD',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
fig=sm.graphics.plot_regress_exog(model,'Admin',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
fig=sm.graphics.plot_regress_exog(model,'Marketing',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
fig=sm.graphics.plot_regress_exog(model,'California',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
fig=sm.graphics.plot_regress_exog(model,'florida',fig=fig)
plt.show()

# %%
model_influence=model.get_influence()
(c, _)=model_influence.cooks_distance

# %%
fig=plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(df)),np.round(c,3))
plt.show()
# Out:
# <ipython-input-58-be8c1d87d660>:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(np.arange(len(df)),np.round(c,3))

# %%
(np.argmax(c),np.max(c))
# Out:
# (49, 0.2639594358495063)

# %%
k=df.shape[1]
n=df.shape[0]
leverage_cutoff=3*((k+1)/n)
leverage_cutoff
# Out:
# 0.48

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()
